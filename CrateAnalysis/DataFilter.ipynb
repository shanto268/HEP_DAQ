# %%
from MuonDataFrame import *

file = "processed_data/events_data_frame_801.ftr"
mdfo = MuonDataFrame(file, isNew=False, d1="last") #Muon Data Frame Object

# %%
mdfo.keepEvents("numLHit", 8, "==")

# %%
mdf = mdfo.events_df

# %%
xmin = 0
xmax = 300
ymin = -0
ymax = 300
nbins = 250
x = "L4"
y = "R4"
mdfo.get2DHistogram(mdf[x].values,
                            mdf[y].values, "{} vs {}".format(x,y),
                            x, y, xmin, xmax,
                            ymin, ymax, nbins)
# Out:
# in module L4vsR4_run_801: 6.0 overflow Events

# %%
mdfo.getPlot(["L1","R2"])

# %%
# %matplotlib notebook 
mdfo.getHistogram("deadtime", nbins=200)

# %%
mdf
# Out:
#         event_num                 event_time  deadtime  \
# 0               0 2020-10-16 17:32:35.058359       753
# 13             13 2020-10-16 17:32:37.708824      3361
# 76             76 2020-10-16 17:32:53.110296      3331
# 92             92 2020-10-16 17:32:57.630861      3470
# 99             99 2020-10-16 17:32:59.361064      3396
# ...           ...                        ...       ...
# 199907     199907 2020-10-17 06:47:48.801538      3367
# 199918     199918 2020-10-17 06:47:51.831683      1203
# 199924     199924 2020-10-17 06:47:53.081927      1269
# 199933     199933 2020-10-17 06:47:55.932199      1253
# 199944     199944 2020-10-17 06:47:58.502422      3081
#
#                                                   ADC  \
# 0       [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 13      [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 76      [1, 31, 32, 33, 29, 20, 26, 6, 7, 16, 16, 23]
# 92      [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# ...

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "numLHit"])

# %%
mdfo.getScatterPlot(["deadtime", "numLHit"])

# %%
mdfo.get3DScatterPlot(["diffL2", "asymL2", "sumL2"])

# %%
mdfo.get3DScatterPlot(["diffL2", "asymL2", "numLHit"])

# %%
mdfo.getScatterPlot(["SCh0", "numLHit"])

# %%
mdfo.getScatterPlot(["asymL1", "numLHit"])

# %%
mdfo.getScatterPlot(["asymL3", "numLHit"])

# %%
mdfo.getFilteredHistogram("asymL1", "numLHit")

# %%
mdfo.getFilteredHistogram("asymL3", "numLHit")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "sumL1"])

# %%
mdfo.get3DScatterPlot(["asymL2", "asymL3", "sumL3"])

# %%
mdfo.keepEvents("sumL1", 400, "<=")
mdfo.keepEvents("sumL2", 400, "<=")
mdfo.keepEvents("sumL3", 400, "<=")
mdfo.keepEvents("sumL4", 400, "<=")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "sumL1"])

# %%
mdfo.get3DScatterPlot(["asymL2", "asymL3", "sumL2"])

# %%
mdfo.keepEvents("sumL1", 180, ">=")
mdfo.keepEvents("sumL2", 180, ">=")
mdfo.keepEvents("sumL3", 180, ">=")
mdfo.keepEvents("sumL4", 180, ">=")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "sumL1"])

# %%
mdfo.get3DScatterPlot(["asymL2", "asymL3", "sumL2"])

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL3", "sumL1"])

# %%
mdfo.keepEvents("sumL1", 200, ">=")
mdfo.keepEvents("sumL2", 200, ">=")
mdfo.keepEvents("sumL3", 200, ">=")
mdfo.keepEvents("sumL4", 200, ">=")

# %%
mdfo.keepEvents("sumL1", 300, "<=")
mdfo.keepEvents("sumL2", 300, "<=")
mdfo.keepEvents("sumL3", 300, "<=")
mdfo.keepEvents("sumL4", 300, "<=")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "sumL1"])

# %%
mdfo.get3DScatterPlot(["asymL2", "asymL3", "sumL2"])

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "deadtime"])

# %%
mdfo.keepEvents("deadtime", 2000, "<=")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "sumL1"])

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "deadtime"])

# %%
mdfo.get3DScatterPlot(["diffL2", "diffL1", "asymL1"])

# %%
mdfo.get3DScatterPlot(["diffL2", "asymL2", "sumL2"])

# %%
mdfo.get3DScatterPlot(["SCh4", "SCh5", "sumL1"])

# %%
mdfo.getHistogram("deadtime", nbins=200)

# %%
mdfo.keepEvents("sumL1", 220, ">=")
mdfo.keepEvents("sumL2", 220, ">=")
mdfo.keepEvents("sumL3", 220, ">=")
mdfo.keepEvents("sumL4", 220, ">=")

mdfo.keepEvents("sumL1", 300, "<=")
mdfo.keepEvents("sumL2", 300, "<=")
mdfo.keepEvents("sumL3", 300, "<=")
mdfo.keepEvents("sumL4", 300, "<=")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "sumL1"])

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "deadtime"])
