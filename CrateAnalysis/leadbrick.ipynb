# %% [markdown]
# # Analysis of Lead Brick Experiment

# %%
from MuonDataFrame import *
file = "processed_data/events_data_frame_24.ftr"
mdfo = MuonDataFrame(file, isNew=False, d1="last") #Muon Data Frame Object
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# <ipython-input-2-02fc679122e8> in <module>
#       1 from MuonDataFrame import *
#       2 file = "processed_data/events_data_frame_24.ftr"
# ----> 3 mdfo = MuonDataFrame(file, isNew=False, d1="last") #Muon Data Frame Object
#
# ~/hep/hep_daq/CAMAC/CrateAnalysis/MuonDataFrame.py in __init__(self, path, isNew, d1)
#     177                             default value = last
#     178         """
# --> 179         self.events_df = pd.read_feather(path, use_threads=True)
#     180         self.nbins = 150
#     181         self.quant_query_terms = []
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/feather_format.py in read_feather(path, columns, use_threads)
#     101     path, _, _, should_close = get_filepath_or_buffer(path)
#     102
# --> 103     df = feather.read_feather(path, columns=columns, use_threads=bool(use_threads))
#     104
#     105     # s3fs only validates the credentials when the file is closed.
#
# ~/anaconda3/lib/python3.8/site-packages/pyarrow/feather.py in read_feather(source, columns, use_threads, memory_map)
#     212     """
#     213     _check_pandas_version()
# --> 214     return (read_table(
#     215         source, columns=columns,
#     216         memory_map=memory_map).to_pandas(use_threads=use_threads))
#
# ~/anaconda3/lib/python3.8/site-packages/pyarrow/feather.py in read_table(source, columns, memory_map)
#     238
#     239     if columns is None:
# --> 240         return reader.read()
#     241
#     242     column_types = [type(column) for column in columns]
#
# ~/anaconda3/lib/python3.8/site-packages/pyarrow/feather.pxi in pyarrow.lib.FeatherReader.read()
#
# ~/anaconda3/lib/python3.8/site-packages/pyarrow/public-api.pxi in pyarrow.lib.pyarrow_wrap_table()
#
# ~/anaconda3/lib/python3.8/site-packages/pyarrow/error.pxi in pyarrow.lib.check_status()
#
# ArrowInvalid: Column 0: In chunk 0: Invalid: Buffer #1 too small in array of type int64 and length 65536: expected at least 524288 byte(s), got 262378

# %%
mdfo.show()
# Out:
#       event_num                 event_time  deadtime  \
# 0             0 2020-10-16 14:04:35.534924      1104
# 1             1 2020-10-16 14:04:35.635247      1358
# 2             2 2020-10-16 14:04:35.775551      3284
# 3             3 2020-10-16 14:04:36.185348      3005
# 4             4 2020-10-16 14:04:36.495455       730
# ...         ...                        ...       ...
# 4995       4995 2020-10-16 14:23:26.685867       636
# 4996       4996 2020-10-16 14:23:26.786323      1111
# 4997       4997 2020-10-16 14:23:26.976267      1005
# 4998       4998 2020-10-16 14:23:27.115956      1174
# 4999       4999 2020-10-16 14:23:27.286042      1000
#
#                                                 ADC  \
# 0     [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 1     [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 2     [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 3     [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 17, 23]
# 4     [1, 31, 33, 33, 29, 21, 27, 6, 7, 16, 17, 23]
# ...                                             ...
# 4995  [1, 32, 32, 33, 29, 21, 26, 6, 7, 16, 17, 23]
# 4996  [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 17, 23]
# 4997  [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 4998  [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 4999  [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
#
#                                                     TDC  l1hit  l2hit  l3hit  \
# 0                                                  None    NaN    NaN    NaN
# 1                        [[4, 118], [7, 118], [9, 129]]    0.0    0.0    0.0
# 2                         [[0, 114], [6, 117], [7, 75]]    1.0    0.0    1.0
# 3     [[1, 114], [3, 114], [6, 85], [7, 118], [10, 1...    0.0    1.0    1.0
# 4             [[1, 114], [3, 126], [7, 116], [10, 125]]    0.0    1.0    0.0
# ...                                                 ...    ...    ...    ...
# 4995                      [[0, 107], [6, 103], [7, 89]]    1.0    0.0    1.0
# 4996  [[1, 129], [4, 122], [6, 87], [7, 137], [9, 124]]    0.0    0.0    1.0
# 4997                               [[1, 131], [7, 137]]    0.0    0.0    0.0
# 4998             [[1, 113], [3, 80], [4, 80], [7, 117]]    0.0    1.0    0.0
# 4999                                               None    NaN    NaN    NaN
#
#       l4hit  r1hit  ...  sumL4  diffL1  diffL2  diffL3  diffL4  asymL1  \
# 0       NaN    NaN  ...    NaN     NaN     NaN     NaN     NaN     NaN
# 1       1.0    0.0  ...    NaN     NaN     NaN     NaN     NaN     NaN
# 2       0.0    0.0  ...    NaN     NaN     NaN    42.0     NaN     NaN
# 3       0.0    1.0  ...    NaN     NaN     NaN   -33.0     NaN     NaN
# 4       0.0    1.0  ...    NaN     NaN     NaN     NaN     NaN     NaN
# ...     ...    ...  ...    ...     ...     ...     ...     ...     ...
# 4995    0.0    0.0  ...    NaN     NaN     NaN    14.0     NaN     NaN
# 4996    1.0    1.0  ...    NaN     NaN     NaN   -50.0     NaN     NaN
# 4997    0.0    1.0  ...    NaN     NaN     NaN     NaN     NaN     NaN
# 4998    0.0    1.0  ...    NaN     NaN     0.0     NaN     NaN     NaN
# 4999    NaN    NaN  ...    NaN     NaN     NaN     NaN     NaN     NaN
#
#       asymL2    asymL3  asymL4  numLHit
# 0        NaN       NaN     NaN        0
# 1        NaN       NaN     NaN        3
# 2        NaN  0.218750     NaN        3
# 3        NaN -0.162562     NaN        5
# 4        NaN       NaN     NaN        4
# ...      ...       ...     ...      ...
# 4995     NaN  0.072917     NaN        3
# 4996     NaN -0.223214     NaN        5
# 4997     NaN       NaN     NaN        2
# 4998     0.0       NaN     NaN        4
# 4999     NaN       NaN     NaN        0
#
# [5000 rows x 46 columns]
