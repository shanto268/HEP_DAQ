# %%
from MuonDataFrame import *
file = "processed_data/events_data_frame_403.h5"
mdfo = MuonDataFrame(file, isNew=False, d1="last") #Muon Data Frame Object 
mdf = mdfo.events_df

# %%
sC = mdfo.get("SmallCounter")

# %%
mdfo.getHistogram("SmallCounter",nbins=100)

# %%
mdfo.keepEvents("SmallCounter",100,">=")

# %%
mdfo.getHistogram("SmallCounter",nbins=100)

# %%
mdfo.keepEvents("SmallCounter",200,"<=")

# %%
mdfo.getHistogram("SmallCounter",nbins=100)

# %%
mdfo.reload()

xmin = -1
xmax = 1
ymin = -1
ymax = 1
bins = 11
t = mdfo.getTValue()
xx = mdfo.x(t)
yy = mdfo.y(t)

mdfo.get2DHistogram(xx,
                    yy,
                    "Z Plane of Small Counter",
                    "X (asym)",
                    "Y (asym)",
                    xmin,
                    xmax,
                    ymin,
                    ymax,
                    nbins=bins,
                    pdf=False,
                    zLog=False)

# %%
mdfo.reload()
mdfo.keepEvents("SmallCounter",100,">=")
mdfo.keepEvents("SmallCounter",200,"<=")

xmin = -1
xmax = 1
ymin = -1
ymax = 1
bins = 11
t = mdfo.getTValue()
xx = mdfo.x(t)
yy = mdfo.y(t)

mdfo.get2DHistogram(xx,
                    yy,
                    "Z Plane of Small Counter",
                    "X (asym)",
                    "Y (asym)",
                    xmin,
                    xmax,
                    ymin,
                    ymax,
                    nbins=bins,
                    pdf=False,
                    zLog=False)

# %% [markdown]
# ## Events Within 2 Degrees

# %%
mdfo.reload()
mdfo.keepEvents("z_angle",2,"<=")
mdfo.getHistogram("SmallCounter",nbins=100)

# %%
mdfo.reload()
mdfo.keepEvents("z_angle",2,"<=")

xmin = -1
xmax = 1
ymin = -1
ymax = 1
bins = 100
t = mdfo.getTValue()
xx = mdfo.x(t)
yy = mdfo.y(t)

mdfo.get2DHistogram(xx,
                    yy,
                    "Z Plane of Small Counter",
                    "X (asym)",
                    "Y (asym)",
                    xmin,
                    xmax,
                    ymin,
                    ymax,
                    nbins=bins,
                    pdf=False,
                    zLog=False)

# %%
mdfo.reload()
mdfo.keepEvents("SmallCounter",100,">=")
mdfo.keepEvents("SmallCounter",200,"<=")
mdfo.keepEvents("z_angle",2,"<=")

xmin = -1
xmax = 1
ymin = -1
ymax = 1
bins = 100
t = mdfo.getTValue()
xx = mdfo.x(t)
yy = mdfo.y(t)

mdfo.get2DHistogram(xx,
                    yy,
                    "Z Plane of Small Counter",
                    "X (asym)",
                    "Y (asym)",
                    xmin,
                    xmax,
                    ymin,
                    ymax,
                    nbins=bins,
                    pdf=False,
                    zLog=False)

# %% [markdown]
# ## Higher Bins

# %% [markdown]
# # Events with no Small Counter Hits

# %%
import copy

mdfo.reload()
mdf1 = mdf[mdf['SmallCounter'].isnull()] #all non hits
mdf2 = mdf[mdf['SmallCounter'] >= 200]
mdf3 = mdf[mdf['SmallCounter'] <= 100]

mdf_list = [mdf1,mdf2,mdf3]
mdf_noSc = mdfo.getMergedMDF(mdf_list)

mdfo_noSc = copy.copy(mdfo)
mdfo_noSc.events_df = mdf_noSc

# %%
mdfo_noSc.getHistogram("SmallCounter",nbins=100)

# %%
xmin = -1
xmax = 1
ymin = -1
ymax = 1
bins = 11
t = mdfo_noSc.getTValue()
xx = mdfo_noSc.x(t)
yy = mdfo_noSc.y(t)

mdfo_noSc.get2DHistogram(xx,
                    yy,
                    "Z Plane of Small Counter",
                    "X (asym)",
                    "Y (asym)",
                    xmin,
                    xmax,
                    ymin,
                    ymax,
                    nbins=bins,
                    pdf=False,
                    zLog=False)

# %%
xmin = -1
xmax = 1
ymin = -1
ymax = 1
bins = 100
t = mdfo_noSc.getTValue()
xx = mdfo_noSc.x(t)
yy = mdfo_noSc.y(t)

mdfo_noSc.get2DHistogram(xx,
                    yy,
                    "Z Plane of Small Counter",
                    "X (asym)",
                    "Y (asym)",
                    xmin,
                    xmax,
                    ymin,
                    ymax,
                    nbins=bins,
                    pdf=False,
                    zLog=False)

# %% [markdown]
# ## Keeping 4 by 4 hits

# %%
mdfo_noSc.reload()
mdfo_noSc.keep4by4Events()

xmin = -1
xmax = 1
ymin = -1
ymax = 1
bins = 100
t = mdfo_noSc.getTValue()
xx = mdfo_noSc.x(t)
yy = mdfo_noSc.y(t)

mdfo_noSc.get2DHistogram(xx,
                    yy,
                    "Z Plane of Small Counter",
                    "X (asym)",
                    "Y (asym)",
                    xmin,
                    xmax,
                    ymin,
                    ymax,
                    nbins=bins,
                    pdf=False,
                    zLog=False)

# %% [markdown]
# ## Keeping Events Within 2 degrees

# %%
mdfo_noSc.reload()
mdfo_noSc.keepEvents("z_angle",2,"<=")

xmin = -1
xmax = 1
ymin = -1
ymax = 1
bins = 11
t = mdfo_noSc.getTValue()
xx = mdfo_noSc.x(t)
yy = mdfo_noSc.y(t)

mdfo_noSc.get2DHistogram(xx,
                    yy,
                    "Z Plane of Small Counter",
                    "X (asym)",
                    "Y (asym)",
                    xmin,
                    xmax,
                    ymin,
                    ymax,
                    nbins=bins,
                    pdf=False,
                    zLog=False)
