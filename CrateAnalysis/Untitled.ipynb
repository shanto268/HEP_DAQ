# %% [markdown]
# # Extracting Muon Position From Asymmetry Data
#
# ## High Level Idea:
# 1. Keep events for L1 channel 11 (asymmetry cut1)
# 1. Keep events for L1 channel 1 (asymmetry cut1)

# %%
from MuonDataFrame import *
ifile = "processed_data/events_data_frame_801.ftr"
mdfo = MuonDataFrame(ifile, isNew=False, d1="last")

# %%
mdf = mdfo.events_df

# %%
mdfo.keepEvents("asymL1", 0.21, ">=")
mdf1 = mdfo.events_df

# %%
mdf1
# Out:
#         event_num                 event_time  deadtime  \
# 139           139 2020-10-16 17:33:12.262549       839
# 300           300 2020-10-16 17:33:54.416732      1104
# 467           467 2020-10-16 17:34:35.381299      1249
# 495           495 2020-10-16 17:34:43.042057      3399
# 566           566 2020-10-16 17:35:02.334107      3326
# ...           ...                        ...       ...
# 199853     199853 2020-10-17 06:47:36.119947      1225
# 199880     199880 2020-10-17 06:47:42.660912      1369
# 199902     199902 2020-10-17 06:47:47.971304       819
# 199907     199907 2020-10-17 06:47:48.801538      3367
# 199967     199967 2020-10-17 06:48:03.862978       790
#
#                                                    ADC  \
# 139      [1, 31, 33, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 300      [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 467      [1, 32, 33, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 495      [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 566     [1, 35, 36, 37, 33, 24, 30, 9, 10, 20, 20, 26]
# ...                                                ...
# 199853   [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 199880   [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 199902   [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 199907   [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 199967   [1, 32, 33, 33, 29, 21, 27, 6, 7, 16, 17, 23]
#
#                                                       TDC  SCh0  SCh1  SCh2  \
# 139     [[0, 127], [1, 77], [3, 90], [4, 125], [9, 116...     1    28    27
# 300     [[0, 115], [1, 73], [3, 126], [4, 82], [6, 115...     1     7    12
# 467     [[0, 118], [1, 68], [3, 124], [4, 110], [6, 12...     1    15    29
# 495      [[0, 122], [1, 73], [3, 84], [4, 117], [9, 130]]     1    37    47
# 566     [[0, 121], [1, 78], [3, 110], [4, 110], [6, 12...     1    56    77
# ...                                                   ...   ...   ...   ...
# 199853  [[0, 123], [1, 80], [3, 87], [4, 121], [6, 126...     1    28    27
# 199880  [[0, 121], [1, 77], [3, 80], [4, 123], [6, 120...     1    28    35
# 199902             [[0, 117], [1, 75], [3, 121], [4, 87]]     1    40    54
# 199907  [[0, 121], [1, 71], [3, 113], [4, 94], [6, 126...     1    61    68
# 199967  [[0, 116], [1, 65], [3, 122], [4, 78], [6, 116...     1    48    59
#
#         SCh3  SCh4  ...  sumL4  diffL1  diffL2  diffL3  diffL4    asymL1  \
# 139        0     9  ...  231.0    50.0   -35.0     NaN     1.0  0.245098
# 300        0     3  ...    NaN    42.0    44.0    24.0     NaN  0.223404
# 467        0     5  ...  251.0    50.0    14.0    41.0     3.0  0.268817
# 495        0    19  ...    NaN    49.0   -33.0     NaN     NaN  0.251282
# 566        0    18  ...    NaN    43.0     0.0    33.0     NaN  0.216080
# ...      ...   ...  ...    ...     ...     ...     ...     ...       ...
# 199853     0     4  ...  215.0    43.0   -34.0    42.0    43.0  0.211823
# 199880     0    17  ...  208.0    44.0   -43.0    34.0    46.0  0.222222
# 199902     0    12  ...    NaN    42.0    34.0     NaN     NaN  0.218750
# 199907     0    17  ...  220.0    50.0    19.0    49.0     2.0  0.260417
# 199967     0    13  ...    NaN    51.0    44.0    42.0     NaN  0.281768
#
#           asymL2    asymL3    asymL4  numLHit
# 139    -0.162791       NaN  0.004329        6
# 300     0.211538  0.116505       NaN        7
# 467     0.059829  0.201970  0.011952        8
# 495    -0.164179       NaN       NaN        5
# 566     0.000000  0.159420       NaN        6
# ...          ...       ...       ...      ...
# 199853 -0.163462  0.200000  0.200000        8
# 199880 -0.211823  0.165049  0.221154        8
# 199902  0.163462       NaN       NaN        4
# 199907  0.091787  0.241379  0.009091        8
# 199967  0.220000  0.221053       NaN        7
#
# [2400 rows x 38 columns]

# %%
mdfo.keepEvents("asymL1", 0.28, "<=")
mdf1 = mdfo.events_df

# %%
mdf1
# Out:
#         event_num                 event_time  deadtime  \
# 139           139 2020-10-16 17:33:12.262549       839
# 300           300 2020-10-16 17:33:54.416732      1104
# 467           467 2020-10-16 17:34:35.381299      1249
# 495           495 2020-10-16 17:34:43.042057      3399
# 566           566 2020-10-16 17:35:02.334107      3326
# ...           ...                        ...       ...
# 199831     199831 2020-10-17 06:47:31.719531      3445
# 199853     199853 2020-10-17 06:47:36.119947      1225
# 199880     199880 2020-10-17 06:47:42.660912      1369
# 199902     199902 2020-10-17 06:47:47.971304       819
# 199907     199907 2020-10-17 06:47:48.801538      3367
#
#                                                    ADC  \
# 139      [1, 31, 33, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 300      [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 467      [1, 32, 33, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 495      [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 566     [1, 35, 36, 37, 33, 24, 30, 9, 10, 20, 20, 26]
# ...                                                ...
# 199831   [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 17, 23]
# 199853   [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 199880   [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 199902   [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 199907   [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
#
#                                                       TDC  SCh0  SCh1  SCh2  \
# 139     [[0, 127], [1, 77], [3, 90], [4, 125], [9, 116...     1    28    27
# 300     [[0, 115], [1, 73], [3, 126], [4, 82], [6, 115...     1     7    12
# 467     [[0, 118], [1, 68], [3, 124], [4, 110], [6, 12...     1    15    29
# 495      [[0, 122], [1, 73], [3, 84], [4, 117], [9, 130]]     1    37    47
# 566     [[0, 121], [1, 78], [3, 110], [4, 110], [6, 12...     1    56    77
# ...                                                   ...   ...   ...   ...
# 199831             [[0, 127], [1, 77], [3, 89], [4, 123]]     1    45    85
# 199853  [[0, 123], [1, 80], [3, 87], [4, 121], [6, 126...     1    28    27
# 199880  [[0, 121], [1, 77], [3, 80], [4, 123], [6, 120...     1    28    35
# 199902             [[0, 117], [1, 75], [3, 121], [4, 87]]     1    40    54
# 199907  [[0, 121], [1, 71], [3, 113], [4, 94], [6, 126...     1    61    68
#
#         SCh3  SCh4  ...  sumL4  diffL1  diffL2  diffL3  diffL4    asymL1  \
# 139        0     9  ...  231.0    50.0   -35.0     NaN     1.0  0.245098
# 300        0     3  ...    NaN    42.0    44.0    24.0     NaN  0.223404
# 467        0     5  ...  251.0    50.0    14.0    41.0     3.0  0.268817
# 495        0    19  ...    NaN    49.0   -33.0     NaN     NaN  0.251282
# 566        0    18  ...    NaN    43.0     0.0    33.0     NaN  0.216080
# ...      ...   ...  ...    ...     ...     ...     ...     ...       ...
# 199831     0    17  ...    NaN    50.0   -34.0     NaN     NaN  0.245098
# 199853     0     4  ...  215.0    43.0   -34.0    42.0    43.0  0.211823
# 199880     0    17  ...  208.0    44.0   -43.0    34.0    46.0  0.222222
# 199902     0    12  ...    NaN    42.0    34.0     NaN     NaN  0.218750
# 199907     0    17  ...  220.0    50.0    19.0    49.0     2.0  0.260417
#
#           asymL2    asymL3    asymL4  numLHit
# 139    -0.162791       NaN  0.004329        6
# 300     0.211538  0.116505       NaN        7
# 467     0.059829  0.201970  0.011952        8
# 495    -0.164179       NaN       NaN        5
# 566     0.000000  0.159420       NaN        6
# ...          ...       ...       ...      ...
# 199831 -0.160377       NaN       NaN        4
# 199853 -0.163462  0.200000  0.200000        8
# 199880 -0.211823  0.165049  0.221154        8
# 199902  0.163462       NaN       NaN        4
# 199907  0.091787  0.241379  0.009091        8
#
# [2365 rows x 38 columns]

# %%
mdfo.getHistogram("sumL1", nbins=200)

# %%
ch11 = mdf["sumL1"].values
ch11
# Out:
# array([218.,  nan,  nan, ...,  nan,  nan,  nan])

# %%
ifile = "processed_data/events_data_frame_801.ftr"
mdfo1 = MuonDataFrame(ifile, isNew=False, d1="last")
mdf = mdfo1.events_df

# %%
mdfo1.keepEvents("asymL1", -0.21, "<=")
mdf2 = mdfo1.events_df

# %%
mdf2
# Out:
#         event_num                 event_time  deadtime  \
# 49             49 2020-10-16 17:32:45.929590      1197
# 272           272 2020-10-16 17:33:47.216203      3065
# 639           639 2020-10-16 17:35:18.955979      3071
# 983           983 2020-10-16 17:36:37.096666       668
# 1011         1011 2020-10-16 17:36:42.874992      3347
# ...           ...                        ...       ...
# 199245     199245 2020-10-17 06:45:10.404485       955
# 199306     199306 2020-10-17 06:45:23.555887      3442
# 199471     199471 2020-10-17 06:46:02.888569      1517
# 199565     199565 2020-10-17 06:46:27.572589      3465
# 199605     199605 2020-10-17 06:46:35.634516      1309
#
#                                                   ADC  \
# 49      [1, 31, 33, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 272     [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 639     [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 983     [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 1011    [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# ...                                               ...
# 199245  [1, 32, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 199306  [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 199471  [1, 32, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 199565  [1, 31, 32, 33, 29, 20, 26, 6, 7, 16, 16, 22]
# 199605  [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 17, 23]
#
#                                                       TDC  SCh0  SCh1  SCh2  \
# 49      [[0, 64], [1, 114], [4, 98], [7, 120], [9, 103...     1    11    10
# 272     [[0, 82], [1, 126], [3, 131], [4, 83], [7, 130...     1    33    48
# 639     [[0, 76], [1, 117], [3, 124], [4, 73], [6, 91]...     1    50    78
# 983     [[0, 80], [1, 129], [3, 79], [4, 121], [7, 133...     1     7    14
# 1011    [[0, 74], [1, 125], [3, 123], [4, 80], [10, 125]]     1    21    24
# ...                                                   ...   ...   ...   ...
# 199245  [[0, 84], [1, 129], [3, 135], [4, 83], [6, 95]...     1    24    35
# 199306  [[0, 77], [1, 122], [3, 88], [4, 109], [6, 87]...     1    70    67
# 199471  [[0, 86], [1, 138], [3, 87], [4, 17], [4, 129]...     1    17    28
# 199565            [[0, 69], [1, 121], [3, 111], [4, 102]]     1    63    81
# 199605  [[0, 73], [1, 116], [4, 105], [6, 87], [7, 111...     1    17    26
#
#         SCh3  SCh4  ...  sumL4  diffL1  diffL2  diffL3  diffL4    asymL1  \
# 49         0     5  ...  196.0   -50.0     NaN     NaN    10.0 -0.280899
# 272        0    11  ...    NaN   -44.0    48.0     NaN     NaN -0.211538
# 639        0    27  ...  208.0   -41.0    51.0   -24.0   -24.0 -0.212435
# 983        0     4  ...    NaN   -49.0   -42.0     NaN     NaN -0.234450
# 1011       0     4  ...    NaN   -51.0    43.0     NaN     NaN -0.256281
# ...      ...   ...  ...    ...     ...     ...     ...     ...       ...
# 199245     0    12  ...    NaN   -45.0    52.0   -33.0     NaN -0.211268
# 199306     0    25  ...  210.0   -45.0   -21.0   -32.0     2.0 -0.226131
# 199471     0     7  ...  224.0   -52.0     NaN     NaN    30.0 -0.232143
# 199565     0    18  ...    NaN   -52.0     9.0     NaN     NaN -0.273684
# 199605     0    11  ...  205.0   -43.0     NaN   -24.0    11.0 -0.227513
#
#           asymL2    asymL3    asymL4  numLHit
# 49           NaN       NaN  0.051020        6
# 272     0.224299       NaN       NaN        6
# 639     0.258883 -0.116505 -0.115385        8
# 983    -0.210000       NaN       NaN        6
# 1011    0.211823       NaN       NaN        5
# ...          ...       ...       ...      ...
# 199245  0.238532 -0.147982       NaN        7
# 199306 -0.106599 -0.155340  0.009524        8
# 199471       NaN       NaN  0.133929        7
# 199565  0.042254       NaN       NaN        4
# 199605       NaN -0.121212  0.053659        7
#
# [1657 rows x 38 columns]

# %%
mdfo1.keepEvents("asymL1", -0.28, ">=")
mdf2 = mdfo1.events_df

# %%
mdf2
# Out:
#         event_num                 event_time  deadtime  \
# 272           272 2020-10-16 17:33:47.216203      3065
# 639           639 2020-10-16 17:35:18.955979      3071
# 983           983 2020-10-16 17:36:37.096666       668
# 1011         1011 2020-10-16 17:36:42.874992      3347
# 1040         1040 2020-10-16 17:36:50.505951      2945
# ...           ...                        ...       ...
# 199245     199245 2020-10-17 06:45:10.404485       955
# 199306     199306 2020-10-17 06:45:23.555887      3442
# 199471     199471 2020-10-17 06:46:02.888569      1517
# 199565     199565 2020-10-17 06:46:27.572589      3465
# 199605     199605 2020-10-17 06:46:35.634516      1309
#
#                                                   ADC  \
# 272     [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 639     [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 983     [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# 1011    [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 1040    [1, 31, 32, 33, 29, 21, 26, 6, 7, 16, 16, 23]
# ...                                               ...
# 199245  [1, 32, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 199306  [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 199471  [1, 32, 32, 33, 29, 21, 27, 6, 7, 16, 16, 23]
# 199565  [1, 31, 32, 33, 29, 20, 26, 6, 7, 16, 16, 22]
# 199605  [1, 31, 32, 33, 29, 21, 27, 6, 7, 16, 17, 23]
#
#                                                       TDC  SCh0  SCh1  SCh2  \
# 272     [[0, 82], [1, 126], [3, 131], [4, 83], [7, 130...     1    33    48
# 639     [[0, 76], [1, 117], [3, 124], [4, 73], [6, 91]...     1    50    78
# 983     [[0, 80], [1, 129], [3, 79], [4, 121], [7, 133...     1     7    14
# 1011    [[0, 74], [1, 125], [3, 123], [4, 80], [10, 125]]     1    21    24
# 1040    [[0, 78], [1, 124], [3, 129], [4, 78], [7, 126...     1    61    79
# ...                                                   ...   ...   ...   ...
# 199245  [[0, 84], [1, 129], [3, 135], [4, 83], [6, 95]...     1    24    35
# 199306  [[0, 77], [1, 122], [3, 88], [4, 109], [6, 87]...     1    70    67
# 199471  [[0, 86], [1, 138], [3, 87], [4, 17], [4, 129]...     1    17    28
# 199565            [[0, 69], [1, 121], [3, 111], [4, 102]]     1    63    81
# 199605  [[0, 73], [1, 116], [4, 105], [6, 87], [7, 111...     1    17    26
#
#         SCh3  SCh4  ...  sumL4  diffL1  diffL2  diffL3  diffL4    asymL1  \
# 272        0    11  ...    NaN   -44.0    48.0     NaN     NaN -0.211538
# 639        0    27  ...  208.0   -41.0    51.0   -24.0   -24.0 -0.212435
# 983        0     4  ...    NaN   -49.0   -42.0     NaN     NaN -0.234450
# 1011       0     4  ...    NaN   -51.0    43.0     NaN     NaN -0.256281
# 1040       0    19  ...    NaN   -46.0    51.0     NaN     NaN -0.227723
# ...      ...   ...  ...    ...     ...     ...     ...     ...       ...
# 199245     0    12  ...    NaN   -45.0    52.0   -33.0     NaN -0.211268
# 199306     0    25  ...  210.0   -45.0   -21.0   -32.0     2.0 -0.226131
# 199471     0     7  ...  224.0   -52.0     NaN     NaN    30.0 -0.232143
# 199565     0    18  ...    NaN   -52.0     9.0     NaN     NaN -0.273684
# 199605     0    11  ...  205.0   -43.0     NaN   -24.0    11.0 -0.227513
#
#           asymL2    asymL3    asymL4  numLHit
# 272     0.224299       NaN       NaN        6
# 639     0.258883 -0.116505 -0.115385        8
# 983    -0.210000       NaN       NaN        6
# 1011    0.211823       NaN       NaN        5
# 1040    0.246377       NaN       NaN        6
# ...          ...       ...       ...      ...
# 199245  0.238532 -0.147982       NaN        7
# 199306 -0.106599 -0.155340  0.009524        8
# 199471       NaN       NaN  0.133929        7
# 199565  0.042254       NaN       NaN        4
# 199605       NaN -0.121212  0.053659        7
#
# [1628 rows x 38 columns]

# %%
mdfo1.getHistogram("sumL1", nbins=200)

# %%
ch0 = mdf2["sumL1"].values
ch0
# Out:
# array([208., 193., 209., ..., 224., 190., 189.])

# %%
bins = 200
plt.hist(ch0, bins, alpha=0.5, label='L1 Ch0')
plt.hist(ch11, bins, alpha=0.5,label='L1 Ch11')
plt.legend(loc='upper right')
plt.title("TDC Sum")
plt.xlim([0,300])
# Out:
# (0.0, 300.0)
