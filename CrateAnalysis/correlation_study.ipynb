# %%
from MuonDataFrame import *
file = "processed_data/events_data_frame_43.h5"
mdfo = MuonDataFrame(file, isNew=False, d1="last") #Muon Data Frame Object

# %%
mdf = mdfo.events_df

# %%
plt.rcParams['figure.figsize'] = [14, 8]
mdfo.allLayerCorrelationPlots()
# Out:
# in module Asymmetry:L1vsL2_run_43: 22.0 overflow Events
# in module Asymmetry:L3vsL4_run_43: 182.0 overflow Events
# in module Asymmetry:L1vsL3_run_43: 120.0 overflow Events
# in module Asymmetry:L2vsL4_run_43: 89.0 overflow Events
# in module Asymmetry:L1vsL4_run_43: 75.0 overflow Events
# in module Asymmetry:L2vsL3_run_43: 136.0 overflow Events

# %%
asymL1 = (mdf['L1'].values - mdf['R1'].values) / (mdf['L1'].values + mdf['R1'].values)
asymL3 = (mdf['L3'].values - mdf['R3'].values) / (mdf['L3'].values + mdf['R3'].values)

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [14, 8]
plt.scatter(asymL1,asymL2)

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL3", "deadtime"])

# %%
mdfo.keepEvents("sumL1", 185, "<=")
mdfo.keepEvents("sumL1", 180, ">=")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "deadtime"])

# %%
mdfo.allLayerCorrelationPlots()
# Out:
# in module Asymmetry:L1vsL2_run_43: 3.0 overflow Events
# in module Asymmetry:L3vsL4_run_43: 14.0 overflow Events
# in module Asymmetry:L1vsL3_run_43: 7.0 overflow Events
# in module Asymmetry:L2vsL4_run_43: 10.0 overflow Events
# in module Asymmetry:L1vsL4_run_43: 7.0 overflow Events
# in module Asymmetry:L2vsL3_run_43: 10.0 overflow Events

# %%
mdfo.keepEvents("deadtime", 1500, "<=")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "deadtime"])

# %%
mdfo.keepEvents("sumL2", 185, "<=")
mdfo.keepEvents("sumL2", 180, ">=")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "deadtime"])

# %%
mdfo.allLayerCorrelationPlots()
# Out:
# in module Asymmetry:L1vsL2_run_43: 0.0 overflow Events
# in module Asymmetry:L3vsL4_run_43: 2.0 overflow Events
# in module Asymmetry:L1vsL3_run_43: 1.0 overflow Events
# in module Asymmetry:L2vsL4_run_43: 1.0 overflow Events
# in module Asymmetry:L1vsL4_run_43: 1.0 overflow Events
# in module Asymmetry:L2vsL3_run_43: 1.0 overflow Events

# %%
mdfo.allLayerCorrelationPlots(nbins=22)
# Out:
# in module Asymmetry:L1vsL2_run_43: 0.0 overflow Events
# in module Asymmetry:L3vsL4_run_43: 2.0 overflow Events
# in module Asymmetry:L1vsL3_run_43: 1.0 overflow Events
# in module Asymmetry:L2vsL4_run_43: 1.0 overflow Events
# in module Asymmetry:L1vsL4_run_43: 1.0 overflow Events
# in module Asymmetry:L2vsL3_run_43: 1.0 overflow Events

# %% [markdown]
# ---

# %%
mdfo.reload()

# %%
mdfo.keepEventsWithinStdDev("sumL1",0.1)

# %%
plt.rcParams['figure.figsize'] = [14, 8]
mdfo.get3DScatterPlot(["asymL1", "asymL2", "deadtime"])

# %% [markdown]
# ---

# %%
from MuonDataFrame import *
file = "processed_data/events_data_frame_43.h5"
mdfo = MuonDataFrame(file, isNew=False, d1="first") #Muon Data Frame Object

# %%
plt.rcParams['figure.figsize'] = [14, 8]
mdfo.allLayerCorrelationPlots()
# Out:
# in module Asymmetry:L1vsL2_run_43: 22.0 overflow Events
# in module Asymmetry:L3vsL4_run_43: 182.0 overflow Events
# in module Asymmetry:L1vsL3_run_43: 120.0 overflow Events
# in module Asymmetry:L2vsL4_run_43: 89.0 overflow Events
# in module Asymmetry:L1vsL4_run_43: 75.0 overflow Events
# in module Asymmetry:L2vsL3_run_43: 136.0 overflow Events

# %%
mdfo.allLayerCorrelationPlots(nbins=22)
# Out:
# in module Asymmetry:L1vsL2_run_43: 22.0 overflow Events
# in module Asymmetry:L3vsL4_run_43: 182.0 overflow Events
# in module Asymmetry:L1vsL3_run_43: 120.0 overflow Events
# in module Asymmetry:L2vsL4_run_43: 89.0 overflow Events
# in module Asymmetry:L1vsL4_run_43: 75.0 overflow Events
# in module Asymmetry:L2vsL3_run_43: 136.0 overflow Events

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "deadtime"])

# %%
mdfo.keepEvents("sumL1", 185, "<=")
mdfo.keepEvents("sumL1", 180, ">=")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "deadtime"])

# %%
mdfo.keepEvents("deadtime", 1500, "<=")

# %%
mdfo.get3DScatterPlot(["asymL1", "asymL2", "deadtime"])
