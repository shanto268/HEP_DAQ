# %%
from MuonDataFrame import *


ifile2 = "processed_data/events_data_frame_304.h5"
mdfo = MuonDataFrame(ifile2, isNew="True", d1="last")
mdf = mdfo.events_df

# %%
mdfo.getHistogram("asymL1")

# %%
mdfo.getHistogram("asymL2")

# %%
mdfo.getHistogram("asymL3")

# %%
mdfo.getHistogram("asymL4")

# %%
mdfo.generateAnaReport()
# Out:
# Creating the report pdf...
# The report file events_data_frame_304.pdf has been created.
