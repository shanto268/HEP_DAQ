# %% [markdown]
# # Development Scripts

# %%
from MuonDataFrame import *
file = "processed_data/events_data_frame_410.h5"
mdfo = MuonDataFrame(file, isNew=False, d1="last") #Muon Data Frame Object 
mdf = mdfo.events_df

# %%
from MuDataFrame import *
file1 = "processed_data/run410.csv"
mdfo1 = MuDataFrame(file1) #Muon Data Frame Object 
mdf1 = mdfo1.events_df

# %%
mdf1.columns
# Out:
# Index(['event_num', 'event_time', 'deadtime', 'l1hit', 'l2hit', 'l3hit',
#        'l4hit', 'r1hit', 'r2hit', 'r3hit', 'r4hit', 'SCh0', 'SCh1', 'SCh2',
#        'SCh3', 'SCh4', 'SCh5', 'SCh6', 'SCh7', 'SCh8', 'SCh9', 'SCh10',
#        'SCh11', 'L1', 'R1', 'L2', 'R2', 'L3', 'R3', 'L4', 'R4', 'ADC0', 'ADC1',
#        'ADC2', 'ADC3', 'ADC4', 'ADC5', 'ADC6', 'ADC7', 'ADC8', 'ADC9', 'ADC10',
#        'ADC11', 'TopCounter', 'BottomCounter', 'sumL1', 'sumL2', 'sumL3',
#        'sumL4', 'diffL1', 'diffL2', 'diffL3', 'diffL4', 'asymL1', 'asymL2',
#        'asymL3', 'asymL4', 'numLHit', 'theta_x1', 'theta_y1', 'theta_x2',
#        'theta_y2', 'z_angle', 'SmallCounter', 'Run_Num'],
#       dtype='object')

# %%
mdfo1.show()
# Out:
#        event_num                  event_time  deadtime  l1hit  l2hit  l3hit  \
# 0              0  2021-02-13 17:51:53.043620         0      1      0      1
# 1              1  2021-02-13 17:51:53.553858         0      1      1      1
# 2              2  2021-02-13 17:51:53.723748         0      1      1      1
# 3              3  2021-02-13 17:51:54.233733         0      1      1      1
# 4              4  2021-02-13 17:51:54.544048         0      1      1      1
# ...          ...                         ...       ...    ...    ...    ...
# 99995      99995  2021-02-14 03:02:40.577578         0      1      1      1
# 99996      99996  2021-02-14 03:02:40.717577         0      1      1      0
# 99997      99997  2021-02-14 03:02:40.897585         0      1      1      1
# 99998      99998  2021-02-14 03:02:41.227664         0      1      1      1
# 99999      99999  2021-02-14 03:02:41.317764         0      1      1      0
#
# ...
